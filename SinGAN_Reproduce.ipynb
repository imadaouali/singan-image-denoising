# %% [markdown]
# # Reproducing SinGAN Results
# -- Google Colab

# %%
! pip install torch==1.4.0 
! pip install torchvision==0.5.0
# Out:
# ...
#      |████████████████████████████████| 753.4MB 22kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.4.0 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
# ...
#      |████████████████████████████████| 4.0MB 12.2MB/s
# ...
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# ...

# %%
#! git clone https://github.com/tamarott/SinGAN.git

# %%
from google.colab import drive
drive.mount('/content/drive',  force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/drive/MVA/RECVIS/Project/SinGAN
# Out:
# /content/drive/My Drive/drive/MVA/RECVIS/Project/SinGAN

# %%
want_animation = False
if want_animation:
  ! python animation.py --input_name 'volacano.png'
# Out:
# Random Seed:  1680
# output already exist

# %%
! python main_train.py --input_name 'seascape.png'
# Out:
# Random Seed:  4797
# trained model already exist

# %%
want_harmonization = False
if want_harmonization:
  ! python harmonization.py --input_name 'seascape.png' --ref_name 'tree.jpg' --harmonization_start_scale 7

# %%
! python main_train.py --input_name 'stone.png'
# Out:
# Random Seed:  3095
# trained model already exist

# %%
want_editing = False
if want_editing:
  ! python editing.py --input_name 'stone.png' --ref_name 'stone_edit.png' --editing_start_scale 7

# %%
! python main_train.py --input_name 'cows.png'
# Out:
# Random Seed:  6383
# trained model already exist

# %%
want_paint = False
if want_paint:
  ! python paint2image.py --input_name 'cows.png' --ref_name 'cows.png' --paint_start_scale 7
